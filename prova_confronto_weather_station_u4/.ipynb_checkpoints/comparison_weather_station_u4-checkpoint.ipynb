# %%
# 20 July 2022, Ago, Ilaria Grecchi (i.grecchi@campus.unimib.it) @ Unimib

# We compare the weather station data (installed on the U4 roof), over a 1.5 h time span.
# The weather station saves data every minute (the wind is an averaged variable, the others should not...)
# More info on the weather station can be found here 
# https://www.davisinstruments.com/products/wireless-vantage-pro2-plus-including-uv-solar-radiation-sensors?variant=39619859939489
# The time in the weather station data is local time (UTC+2), whereas it is UTC in the sparvio sensor.

# The sensor was shaded with a sheet of brown paper, to avoid being exposed to the sun.

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <img src="./WhatsApp Image 2022-07-20 at 14.22.21.jpeg" width=400/>

# %%
# Read the weather station data.
filename = 'weather_data.txt'
df = pd.read_csv(filename,sep='\t')

temp = df['tempout']
time = df['time']
outhum = df['outhum']
wspeed = df['wspeed']

df
# Out:
#       time  tempout  hitemp  lowtemp  outhum  dewpt  wspeed wdir  windrun  \
# 0    10:20     31.1    31.1     31.1      29   11.0     0.9   SE     0.05
# 1    10:21     31.2    31.2     31.1      28   10.5     0.9    E     0.05
# 2    10:22     31.3    31.3     31.2      28   10.6     0.4   NE     0.03
# 3    10:23     31.3    31.3     31.3      28   10.6     0.4  WSW     0.03
# 4    10:24     31.4    31.4     31.3      28   10.7     0.9    E     0.05
# ..     ...      ...     ...      ...     ...    ...     ...  ...      ...
# 103  12:03     32.3    32.3     32.3      29   12.0     0.9    E     0.05
# 104  12:04     32.4    32.4     32.3      30   12.6     1.3  ESE     0.08
# 105  12:05     32.4    32.4     32.4      29   12.1     0.9   SE     0.05
# 106  12:06     32.6    32.6     32.4      29   12.2     1.3  ESE     0.08
# 107  12:07     32.6    32.6     32.6      29   12.3     1.8  ESE     0.11
#
#      hispeed hidir  wchill  hindex   thw  thsw    pres
# 0        1.3    SE    31.1    29.9  29.9  35.7  1018.9
# 1        1.3    SE    31.2    29.8  29.8  35.6  1018.9
# 2        0.9   ENE    31.3    29.9  29.9  35.8  1019.0
# 3        0.4     E    31.3    30.0  30.0  35.8  1018.9
# 4        1.3     E    31.4    30.2  30.2  36.0  1018.9
# ..       ...   ...     ...     ...   ...   ...     ...
# 103      2.2   SSE    32.3    31.2  31.2  37.4  1018.3
# 104      2.7   SSE    32.4    31.4  31.4  37.6  1018.3
# 105      1.8   ESE    32.4    31.3  31.3  37.5  1018.3
# 106      2.2   ESE    32.6    31.4  31.4  37.6  1018.4
# 107      3.1   ESE    32.6    31.6  31.6  37.8  1018.3
#
# [108 rows x 16 columns]

# %%
# Generate an array of UTC time for the weather station time range.
time_utc = np.datetime64('2022-07-20T08:20') + np.arange(0,108,np.timedelta64(1,'m'))

# %%
plt.figure(figsize=(16,8))
plt.plot(time_utc,temp,'.')
plt.xlabel('UTC time',fontsize=14)
plt.ylabel('Air temperature [°C]',fontsize=14)
plt.grid()

# %%
# Read the sparvio sensor output.

filename = '20220720_083012.csv'
df_s = pd.read_csv(filename,sep=';',skiprows=9)

# Define the UTC time axis
time_s = df_s['Time (UTC)']
time_utc_s = np.zeros((len(time_s),),dtype='datetime64[ms]')
for tt,instant in enumerate(np.array(time_s)):
    str_instant = '2022-07-20T'+instant
    time_utc_s[tt] = np.datetime64(str_instant)

wspeed_s = df_s[' C.wspd']
wspeed_s_sm = df_s[' C.wspd'].rolling(300, min_periods=1, center=True).mean()

temp_tri = df_s[' C.temp']
temp_tri_sm = df_s[' C.temp'].rolling(300, min_periods=1, center=True).mean()
rh_tri = df_s[' C.rh']
rh_tri_sm = df_s[' C.rh'].rolling(300, min_periods=1, center=True).mean()

df_s
# Out:
#          Time (UTC)  SKH1_70727633.pr  SKH1_70727633.bat  SKH1_70727633.temp  \
# 0      08:30:12.421            100098              8.012               33.06
# 1      08:30:12.502
# 2      08:30:12.640
# 3      08:30:12.837            100099              8.019               33.16
# 4      08:30:13.043
# ...             ...               ...                ...                 ...
# 28380  10:04:47.874
# 28381  10:04:48.074
# 28382  10:04:48.287
# 28383  10:04:48.474
# 28384  10:04:48.674            100045              7.522               37.76
#
#        SKH1_70727633.rh   C.wspd   C.wdir   C.windU   C.windV   C.windW  \
# 0                 34.76     0.31       69     -0.28     -0.11     -0.05
# 1                           0.31       69     -0.28     -0.11     -0.05
# 2                           0.31       58     -0.25     -0.16     -0.10
# 3                 35.52     0.21       75     -0.20     -0.05     -0.07
# 4                           0.13       64     -0.09     -0.05     -0.07
# ...                 ...      ...      ...       ...       ...       ...
# 28380                       0.13      145     -0.07      0.09     -0.05
# 28381                       0.13      332      0.06     -0.11     -0.03
# 28382                       0.22      271      0.21      0.00     -0.07
# 28383                       0.26      265      0.24      0.02     -0.10
# 28384             24.96     0.20      331      0.06     -0.10     -0.16
#
#         C.temp   C.rh    C.pr   C.pitch   C.roll   C.heading
# 0        28.41   46.3  100284      -9.9    -51.2           0
# 1        28.41   46.3  100284      -9.9    -51.2           0
# 2        28.42   46.3  100284     -10.6    -50.8           0
# 3        28.49   46.1  100283     -10.6    -50.9           0
# 4        28.43   46.3  100284     -11.0    -50.1           0
# ...        ...    ...     ...       ...      ...         ...
# 28380    28.55   53.6  100253       5.8      3.5           0
# 28381    28.89   52.6  100253       6.4      2.5           0
# 28382    29.00   52.3  100254       5.6      1.9           0
# 28383    29.50   50.8  100253       5.2      1.1           0
# 28384    30.25   48.7  100252       5.7      1.3           0
#
# [28385 rows x 16 columns]

# %%
# Determine the width of the rolling window corresponding to a minute
dt = (time_utc_s[-1]-time_utc_s[0])/len(time_utc_s)
print(dt)
60e3/199
# Out:
# 199 milliseconds
# 301.5075376884422

# %%
df_skh1 = pd.read_csv(filename,sep=';',skiprows=9,usecols=[0,1,2,3,4],na_values=' ')#skip_blank_lines=True)
temp_skh1 = df_skh1[' SKH1_70727633.temp']
rh_skh1 = df_skh1[' SKH1_70727633.rh']
temp_skh1_sm = temp_skh1.rolling(300, min_periods=1, center=True).mean(skipna=True)
rh_skh1_sm = rh_skh1.rolling(300, min_periods=1, center=True).mean(skipna=True)
df_skh1
# Out:
#         Time (UTC)   SKH1_70727633.pr   SKH1_70727633.bat  \
# 0     10:45:51.970            99814.0               7.473
# 1     10:45:51.994            99813.0               7.459
# 2     10:45:52.990            99811.0               7.500
# 3     10:45:53.990            99813.0               7.470
# 4     10:45:54.990            99819.0               7.477
# ...            ...                ...                 ...
# 2217  11:22:44.905            99781.0               7.419
# 2218  11:22:45.905            99781.0               7.425
# 2219  11:22:46.905            99783.0               7.436
# 2220  11:22:47.905            99783.0               7.422
# 2221  11:22:48.905            99778.0               7.412
#
#        SKH1_70727633.temp   SKH1_70727633.rh
# 0                   31.45              48.27
# 1                     NaN                NaN
# 2                   31.53              48.74
# 3                   31.62              49.04
# 4                   31.69              49.01
# ...                   ...                ...
# 2217                41.63              26.22
# 2218                41.64              26.13
# 2219                41.59              26.04
# 2220                41.49              25.91
# 2221                41.33              25.92
#
# [2222 rows x 5 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(time_utc_s,wspeed_s,'.')
plt.plot(time_utc_s,wspeed_s_sm,'-r')
plt.plot(time_utc,wspeed,'o')
plt.xlabel('UTC time',fontsize=14)
plt.ylabel('Wind speed [m/s]',fontsize=14)
plt.grid()
plt.legend(['drone','drone 1 min','weather station'],fontsize=14)

# %%
plt.figure(figsize=(16,8))
plt.plot(time_utc_s,rh_tri,'.')
plt.plot(time_utc_s,rh_tri_sm,'-r')
plt.plot(time_utc,outhum,'o')
plt.plot(time_utc_s,rh_skh1,'^')
plt.plot(time_utc_s,rh_skh1_sm,'-k')
plt.xlabel('UTC time',fontsize=14)
plt.ylabel('RH [%]',fontsize=14)
plt.grid()
plt.legend(['drone','drone 1 min','weather station','skh1','skh1 1 min'],fontsize=14)

# %%
plt.figure(figsize=(16,8))
plt.plot(time_utc_s,temp_tri,'.')
plt.plot(time_utc_s,temp_tri_sm,'-r')
plt.plot(time_utc,temp,'o')
plt.plot(time_utc_s,temp_skh1,'^')
plt.plot(time_utc_s,temp_skh1_sm,'-k')
plt.xlabel('UTC time',fontsize=14)
plt.ylabel('Air temperature [°C]',fontsize=14)
plt.grid()
plt.legend(['drone','drone 1 min','weather station','skh1','skh1 1 min'],fontsize=14)

# %%
# 28th July 2022, Ago, Pietro @ Unimib
# The sensor on SKH1 is shaded first with a thick black paper (cartone) and then with the same brow sheet of paper
# used during the comparison with the weather station for 15 minutes each, roughly.

# %% [markdown]
# <img src="./IMG_20220728_132402.jpg" width=400/>
# <img src="./IMG_20220728_132345.jpg" width=400/>

# %%
filename = '20220728_104551.csv'

df_skh1 = pd.read_csv(filename,sep=';',skiprows=6,na_values=' ')#skip_blank_lines=True)

temp_skh1 = df_skh1[' SKH1_70727633.temp']
rh_skh1 = df_skh1[' SKH1_70727633.rh']
temp_skh1_sm = temp_skh1.rolling(300, min_periods=1, center=True).mean(skipna=True)
rh_skh1_sm = rh_skh1.rolling(300, min_periods=1, center=True).mean(skipna=True)
df_skh1

# %%
# Define the UTC time axis
time_s = df_skh1['Time (UTC)']
time_utc_s = np.zeros((len(time_s),),dtype='datetime64[ms]')
for tt,instant in enumerate(np.array(time_s)):
    str_instant = '2022-07-20T'+instant
    time_utc_s[tt] = np.datetime64(str_instant)

# %%
plt.figure(figsize=(16,8))

plt.plot(time_utc_s,temp_skh1,'^')
plt.plot(time_utc_s,temp_skh1_sm,'-k')
plt.xlabel('UTC time',fontsize=14)
plt.ylabel('Air temperature [°C]',fontsize=14)
plt.grid()
plt.legend(['skh1','skh1 1 min'],fontsize=14)

# %%
# The black paper box is replaced with the brown paper at around 11:00 UTC.
# A warming trend is visible even with the black box (~1.5°C in 15 minutes on the smoothed signal).
# This might be due to the warming due to the stone bench. This trend should be compared with the morning warming.
# When the brow paper is used to shade the sensor, fluctuations get larger, the mean value increases and the trend 
# is no longer clearly visible (maybe because of the larger fluctuations).

# USARE IL CILINDRETTO DEI RULLINI FOTOGRAFICI.
