# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
filename = '20220511_125102.csv'
df = pd.read_csv(filename,sep=';',skiprows=9)
df
# Out:
#         Time (UTC)  SKH1_70727633.pr  SKH1_70727633.bat  SKH1_70727633.temp  \
# 0     12:51:02.973            100284                7.4               32.12
# 1     12:51:03.101
# 2     12:51:03.286            100286              7.389               32.12
# 3     12:51:03.487
# 4     12:51:03.685
# ...            ...               ...                ...                 ...
# 2586  12:59:40.073
# 2587  12:59:40.273
# 2588  12:59:40.473            100238              7.285               28.88
# 2589  12:59:40.673
# 2590  12:59:40.874
#
#       SKH1_70727633.rh  SKH1_70727633.lat  SKH1_70727633.lon  \
# 0                40.03          45.510326           9.211955
# 1
# 2                39.65          45.510341           9.212005
# 3
# 4
# ...                ...                ...                ...
# 2586
# 2587
# 2588             30.07          45.510135           9.211613
# 2589
# 2590
#
#       SKH1_70727633.alt   C.wspd   C.wdir   C.windU   C.windV   C.windW  \
# ...

# %%
plt.plot(df['Time (UTC)'],df[' C.wspd'])

# %%
plt.plot(df['Time (UTC)'],df[' C.wdir'],'.')
